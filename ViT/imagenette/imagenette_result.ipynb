# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 400
import matplotlib.pyplot as plt

# %%
a = [0.976769, 0.975713, 0.976769]
a1 = [0.974657,0.977825,0.978881]
a2 = [0.978881,0.976769, 0.982049]
a4 = [1,2,3]
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot(a4, a, "-b", label="1 pct wrong label")
plt.plot(a4,a1,"-g", label = "25 pct wrong label")
plt.plot(a4, a2, "-r", label = "50 pct wrong label")
plt.legend(loc="upper left")
plt.show()
