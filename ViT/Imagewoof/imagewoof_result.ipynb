# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 400

# %%
import matplotlib.pyplot as plt

# %%
a = [0.902851, 0.913411, 0.928194]

# %%
a1 = [0.897571,0.911299,0.926082]

# %%
a2 = [0.903907,0.925026, 0.935586]

# %%
a4 = [1,2,3]

# %%
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot(a4, a, "-b", label="1 pct wrong label")
plt.plot(a4,a1,"-g", label = "25 pct wrong label")
plt.plot(a4, a2, "-r", label = "50 pct wrong label")
plt.legend(loc="upper left")
plt.savefig("imagewoof.png")
plt.show()

# %%
plt.savefig("imagenette.png")
